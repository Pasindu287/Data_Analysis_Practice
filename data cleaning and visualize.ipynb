# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
local_guides_data=pd.read_csv("local_guides.csv")
restaurants  = pd.read_csv('reviews.csv')

# %%
local_guides_data.columns
# Out:
# Index(['ID', 'NAME', 'LEVEL', 'SCORE', 'REVIEWS', 'RATINGS', 'PHOTOS',
#        'VIDEOS', 'ANSWERS', 'EDITS', 'PLACES', 'ROADS', 'FACTS', 'QnA',
#        'LISTS'],
#       dtype='object')

# %%
 local_guides_data
# Out:
#          ID                NAME    LEVEL  SCORE  REVIEWS  RATINGS  PHOTOS  \
# 0    600001          azam hamza  Level 5  1~275     86.0     33.0    45.0
# 1    600002       Dimas Prihadi  Level 6  1~689     49.0     46.0   147.0
# 2    600003          Udi Keidar  Level 7  6~857    255.0     19.0   722.0
# 3    600004  Charmi Lankeshwari  Level 5  1~085     29.0     73.0    73.0
# 4    600005      menaka Indunil  Level 4    268     11.0     16.0    14.0
# ..      ...                 ...      ...    ...      ...      ...     ...
# 510  600511      Aharon Shmueli  Level 4    300     15.0      5.0    25.0
# 511  600512     Nadeesha Paulis  Level 7  6~863    154.0      5.0   568.0
# 512  600513      Isuru Wilegoda  Level 7  7~234     86.0     22.0   184.0
# 513  600514     Zafar Ahmed Zia  Level 6  3~006      4.0     55.0   554.0
# 514  600515      Raizar Moulana  Level 5  1~257     81.0    214.0    11.0
#
#      VIDEOS  ANSWERS  EDITS  PLACES  ROADS  FACTS  QnA  LISTS
# ...

# %%
local_guides_data.shape
# Out:
# (515, 15)

# %%
local_guides_data["REVIEWS"].value_counts()
# Out:
# 27.0     10
# 32.0     10
# 20.0     10
# 17.0      8
# 23.0      8
#          ..
# 3.0       1
# 65.0      1
# 89.0      1
# 451.0     1
# 623.0     1
# Name: REVIEWS, Length: 186, dtype: int64

# %%
local_guides_data["RATINGS"].value_counts()
# Out:
# 5.0      32
# 1.0      24
# 2.0      21
# 8.0      20
# 3.0      19
#          ..
# 96.0      1
# 216.0     1
# 50.0      1
# 94.0      1
# 245.0     1
# Name: RATINGS, Length: 122, dtype: int64

# %%
local_guides_data.isna().sum()
# Out:
# ID          0
# NAME        5
# LEVEL      21
# SCORE       5
# REVIEWS     4
# RATINGS     3
# PHOTOS      1
# VIDEOS      1
# ANSWERS     0
# EDITS       0
# PLACES      0
# ROADS       0
# FACTS       0
# QnA         0
# LISTS       0
# dtype: int64

# %%
local_guides_data
# Out:
#          ID                NAME    LEVEL  SCORE  REVIEWS  RATINGS  PHOTOS  \
# 0    600001          azam hamza  Level 5  1~275     86.0     33.0    45.0
# 1    600002       Dimas Prihadi  Level 6  1~689     49.0     46.0   147.0
# 2    600003          Udi Keidar  Level 7  6~857    255.0     19.0   722.0
# 3    600004  Charmi Lankeshwari  Level 5  1~085     29.0     73.0    73.0
# 4    600005      menaka Indunil  Level 4    268     11.0     16.0    14.0
# ..      ...                 ...      ...    ...      ...      ...     ...
# 510  600511      Aharon Shmueli  Level 4    300     15.0      5.0    25.0
# 511  600512     Nadeesha Paulis  Level 7  6~863    154.0      5.0   568.0
# 512  600513      Isuru Wilegoda  Level 7  7~234     86.0     22.0   184.0
# 513  600514     Zafar Ahmed Zia  Level 6  3~006      4.0     55.0   554.0
# 514  600515      Raizar Moulana  Level 5  1~257     81.0    214.0    11.0
#
#      VIDEOS  ANSWERS  EDITS  PLACES  ROADS  FACTS  QnA  LISTS
# ...

# %%
local_guides_data=local_guides_data.drop(["EDITS","LISTS","ROADS"],axis=1)

# %%
local_guides_data
# Out:
#          ID                NAME    LEVEL  SCORE  REVIEWS  RATINGS  PHOTOS  \
# 0    600001          azam hamza  Level 5  1~275     86.0     33.0    45.0
# 1    600002       Dimas Prihadi  Level 6  1~689     49.0     46.0   147.0
# 2    600003          Udi Keidar  Level 7  6~857    255.0     19.0   722.0
# 3    600004  Charmi Lankeshwari  Level 5  1~085     29.0     73.0    73.0
# 4    600005      menaka Indunil  Level 4    268     11.0     16.0    14.0
# ..      ...                 ...      ...    ...      ...      ...     ...
# 510  600511      Aharon Shmueli  Level 4    300     15.0      5.0    25.0
# 511  600512     Nadeesha Paulis  Level 7  6~863    154.0      5.0   568.0
# 512  600513      Isuru Wilegoda  Level 7  7~234     86.0     22.0   184.0
# 513  600514     Zafar Ahmed Zia  Level 6  3~006      4.0     55.0   554.0
# 514  600515      Raizar Moulana  Level 5  1~257     81.0    214.0    11.0
#
#      VIDEOS  ANSWERS  PLACES  FACTS  QnA
# ...

# %%
local_guides_data.isna().sum()
# Out:
# ID          0
# NAME        5
# LEVEL      21
# SCORE       5
# REVIEWS     4
# RATINGS     3
# PHOTOS      1
# VIDEOS      1
# ANSWERS     0
# PLACES      0
# FACTS       0
# QnA         0
# dtype: int64

# %%
local_guides_data.shape
# Out:
# (515, 12)

# %%
local_guides_data=local_guides_data.dropna(subset=["NAME","LEVEL","SCORE"]) 
#drop null values

# %%
local_guides_data.isna().sum()
# Out:
# ID         0
# NAME       0
# LEVEL      0
# SCORE      0
# REVIEWS    0
# RATINGS    0
# PHOTOS     0
# VIDEOS     0
# ANSWERS    0
# PLACES     0
# FACTS      0
# QnA        0
# dtype: int64

# %%
local_guides_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 489 entries, 0 to 514
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       489 non-null    int64
#  1   NAME     489 non-null    object
#  2   LEVEL    489 non-null    object
#  3   SCORE    489 non-null    object
#  4   REVIEWS  489 non-null    float64
#  5   RATINGS  489 non-null    float64
#  6   PHOTOS   489 non-null    float64
#  7   VIDEOS   489 non-null    float64
#  8   ANSWERS  489 non-null    int64
#  9   PLACES   489 non-null    int64
#  10  FACTS    489 non-null    int64
#  11  QnA      489 non-null    int64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 49.7+ KB

# %%
local_guides_data.describe()
# Out:
#                   ID      REVIEWS      RATINGS        PHOTOS       VIDEOS  \
# count     489.000000   489.000000   489.000000    489.000000   489.000000
# mean   600256.801636   136.051125    52.955010    494.897751    47.773006
# std       147.977303   495.770504   192.197905   2822.923556   561.538040
# min    600001.000000     1.000000     0.000000      0.000000     0.000000
# 25%    600131.000000    26.000000     6.000000     10.000000     0.000000
# 50%    600257.000000    51.000000    17.000000     52.000000     0.000000
# 75%    600383.000000   119.000000    51.000000    236.000000     2.000000
# max    600515.000000  6193.000000  2397.000000  35429.000000  7185.000000
#
#              ANSWERS       PLACES         FACTS         QnA
# count     489.000000   489.000000    489.000000  489.000000
# mean     1467.513292    21.247444    397.192229   10.501022
# std     11764.229066   154.325124   4019.030281   30.760386
# min         0.000000     0.000000      0.000000    0.000000
# ...

# %%
local_guides_data.head()
# Out:
#        ID                NAME    LEVEL  SCORE  REVIEWS  RATINGS  PHOTOS  \
# 0  600001          azam hamza  Level 5  1~275     86.0     33.0    45.0
# 1  600002       Dimas Prihadi  Level 6  1~689     49.0     46.0   147.0
# 2  600003          Udi Keidar  Level 7  6~857    255.0     19.0   722.0
# 3  600004  Charmi Lankeshwari  Level 5  1~085     29.0     73.0    73.0
# 4  600005      menaka Indunil  Level 4    268     11.0     16.0    14.0
#
#    VIDEOS  ANSWERS  PLACES  FACTS  QnA
# 0     0.0       40       1      1    0
# 1     0.0      274       4      2    5
# 2     4.0      266       1      4    5
# 3     1.0      210       0      1    1
# 4     0.0       48       0      0    1

# %%
score=local_guides_data[["SCORE"]]
score.describe()
# Out:
#         SCORE
# count     489
# unique    416
# top     3~099
# freq        5

# %%
array=local_guides_data[["RATINGS"]].values

# %%
bam=array[:,0]<5.0
print(bam.sum())
# Out:
# 88

# %%
local_guides_data['SCORE']=local_guides_data['SCORE'].str.replace(r'\D', '').astype(int)
local_guides_data['LEVEL']=local_guides_data['LEVEL'].str.replace(r'\D', '').astype(int)
local_guides_data=local_guides_data.sort_values("SCORE")
local_guides_data.to_csv("local_guides_cleaned.csv")
local_guides_data
# Out:
# <ipython-input-23-08c940b382e4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   local_guides_data['SCORE']=local_guides_data['SCORE'].str.replace(r'\D', '').astype(int)
# <ipython-input-23-08c940b382e4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   local_guides_data['LEVEL']=local_guides_data['LEVEL'].str.replace(r'\D', '').astype(int)
#          ID                    NAME  LEVEL   SCORE  REVIEWS  RATINGS   PHOTOS  \
# ...

# %%
local_guides_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 489 entries, 351 to 438
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       489 non-null    int64
#  1   NAME     489 non-null    object
#  2   LEVEL    489 non-null    int32
#  3   SCORE    489 non-null    int32
#  4   REVIEWS  489 non-null    float64
#  5   RATINGS  489 non-null    float64
#  6   PHOTOS   489 non-null    float64
#  7   VIDEOS   489 non-null    float64
#  8   ANSWERS  489 non-null    int64
#  9   PLACES   489 non-null    int64
#  10  FACTS    489 non-null    int64
#  11  QnA      489 non-null    int64
# dtypes: float64(4), int32(2), int64(5), object(1)
# memory usage: 45.8+ KB

# %%
sns.pairplot(local_guides_data)

# %%
sns.distplot(local_guides_data["RATINGS"])

# %%
plt.scatter(local_guides_data['LEVEL'], local_guides_data['RATINGS'])
plt.xlabel('Level')
plt.ylabel('Ratings')
# Out:
# Text(0, 0.5, 'Ratings')

# %%
sns.countplot(local_guides_data["REVIEWS"],label="reviews")

# %%
local_guides_data.plot.hexbin(x="SCORE", y="LEVEL", gridsize=10);
local_guides_data.plot.hexbin(x="SCORE", y="REVIEWS", gridsize=10);

# %%
features=['LEVEL', 'REVIEWS', 'RATINGS', 'PHOTOS','VIDEOS','ANSWERS','PLACES', "FACTS","QnA"]
X=local_guides_data[features]
X.describe()
# Out:
#             LEVEL      REVIEWS      RATINGS        PHOTOS       VIDEOS  \
# count  489.000000   489.000000   489.000000    489.000000   489.000000
# mean     5.588957   136.051125    52.955010    494.897751    47.773006
# std      1.134753   495.770504   192.197905   2822.923556   561.538040
# min      4.000000     1.000000     0.000000      0.000000     0.000000
# 25%      5.000000    26.000000     6.000000     10.000000     0.000000
# 50%      6.000000    51.000000    17.000000     52.000000     0.000000
# 75%      6.000000   119.000000    51.000000    236.000000     2.000000
# max     10.000000  6193.000000  2397.000000  35429.000000  7185.000000
#
#              ANSWERS       PLACES         FACTS         QnA
# count     489.000000   489.000000    489.000000  489.000000
# mean     1467.513292    21.247444    397.192229   10.501022
# std     11764.229066   154.325124   4019.030281   30.760386
# min         0.000000     0.000000      0.000000    0.000000
# ...
